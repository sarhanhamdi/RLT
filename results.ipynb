# %%
import pandas as pd

# %%
reg = pd.read_csv('results/metrics_regression.csv')
clf = pd.read_csv('results/metrics_classification.csv')

# %%
reg.head(10)
# Out:
#        dataset   task_type       model metric      value          scenario  \
# 0  HousingData  regression          RF    MSE  10.368661  real_HousingData
# 1  HousingData  regression          ET    MSE  11.823561  real_HousingData
# 2  HousingData  regression         GBR    MSE   8.527887  real_HousingData
# 3  HousingData  regression       Lasso    MSE  21.887440  real_HousingData
# 4  HousingData  regression  ElasticNet    MSE  21.897292  real_HousingData
# 5  HousingData  regression         RLT    MSE  77.330214  real_HousingData
# 6   parkinsons  regression          RF    MSE   0.001470   real_parkinsons
# 7   parkinsons  regression          ET    MSE   0.001471   real_parkinsons
# 8   parkinsons  regression         GBR    MSE   0.000356   real_parkinsons
# 9   parkinsons  regression       Lasso    MSE   0.000767   real_parkinsons
#
#   source
# 0   real
# 1   real
# 2   real
# 3   real
# 4   real
# 5   real
# 6   real
# 7   real
# 8   real
# 9   real

# %%
print(clf
     )
# Out:
#              dataset       task_type              model metric     value  \
# 0              sonar  classification                 RF    ACC  0.841270
# 1              sonar  classification                 ET    ACC  0.857143
# 2              sonar  classification                GBC    ACC  0.793651
# 3              sonar  classification           LogRegL2    ACC  0.698413
# 4              sonar  classification                RLT    ACC  0.539683
# ..               ...             ...                ...    ...       ...
# 270  scenario1_p1000  classification    RLT_moderate_k2    ACC  0.466667
# 271  scenario1_p1000  classification    RLT_moderate_k5    ACC  0.466667
# 272  scenario1_p1000  classification  RLT_aggressive_k1    ACC  0.600000
# 273  scenario1_p1000  classification  RLT_aggressive_k2    ACC  0.600000
# 274  scenario1_p1000  classification  RLT_aggressive_k5    ACC  0.600000
#
#        scenario     source
# 0    real_sonar       real
# 1    real_sonar       real
# ...
